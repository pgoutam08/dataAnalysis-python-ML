# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
company = ['GOOGL','APPL','FB', 'AMAZN']
rev = [98, 132, 79, 110]
profit = [23,40, 19,10]

# %%
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.xticks(ypos, company)
plt.ylabel('Revenue(bln)')
plt.title('US Tech ')
plt.bar(xpos-0.2, rev, width=0.4, label='Revenue')
plt.bar(xpos+0.2,profit, width=0.4, label='Profit')
plt.legend()

# %%
plt.yticks(ypos, company)
plt.xlabel('Revenue(bln)')
plt.title('US Tech ')
plt.barh(xpos-0.2, rev, label='Revenue')
plt.barh(xpos+0.2,profit, label='Profit')
plt.legend()

# %%
exp_vals = [1200, 890,230, 433,690]
exp_labels = ["Home Rent", "Food", "Phone/internet bill", "Car", "Other utils"]

# %%
plt.axis("equal")
plt.pie(exp_vals, labels=exp_labels, radius= 1.5, autopct="%0.2f%%", shadow=True,
        explode=[0.05,0,0,0,0], startangle=90, pctdistance=0.7, colors=["green","red","blue","cyan","magenta"])
#plt.show()
plt.savefig("C:\\Users\\pattargv\\Desktop\\Pandas\\Expenditure.png", bbox_inches="tight", transparent=True, pad_inches=0.2,orientation='landscape')

# %%
company=['GOOGL','AMZN','MSFT','FB']

revenue=[90,136,89,27]

# %%
plt.barh(company,revenue)
plt.xlabel('Revenue(bln)')
plt.title("US Tech shares")
plt.savefig("C:\\Users\\pattargv\\Desktop\\Pandas\\US_Tech_Shares1", bbox_inches="tight", pad_inches=0.5)

# %%
import pandas as pd
import matplotlib
matplotlib.style.use('ggplot')
df = pd.DataFrame({ 'sample1':['foo','bar','bar','qux'], 'score':[5,9,1,7]})
sum_df = df.groupby("sample1").sum()
pie = sum_df.plot(kind="pie", figsize=(6,6), legend = False, use_index=False, subplots=True, colormap="Pastel1")

# %%
fig = pie[0].get_figure()
fig.savefig("C:\\Users\\pattargv\\Desktop\\Pandas\\myplot")

# %%
type(pie)
# Out:
# numpy.ndarray

# %%
pie[0]
